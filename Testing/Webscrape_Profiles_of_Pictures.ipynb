# %% [markdown]
# # Webscraping Photos to Train Tensor Flow Model
#
# I will be downloading pictures off of tinder to be saved down and to be analyzed for a data science project. I will be using modern methods in order to extract data	 and will be posting all links that I use or reference. These blocks of code will be demonstrating how to get acess into the API and will be able to download pictures to be trained to go into my massive collection for AI training.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# X-Auth token 'IN THE CHROME UNDER CORE=LOCAL=EN'
#
# Base URL = 'https://api.gotinder.com/v2/recs/core?locale=en'

# %%
import requests
import os
import time

# set the URL of the API endpoint and the auth key
url = "https://api.gotinder.com/v2/recs/core?locale=en"
auth_key = "APIKEYGOESHERE"

# set the save folder for the downloaded images

save_folder = "/Volumes/4TB HD/Tinder_AI Training/Female_Pics"

if not os.path.exists(save_folder):
    os.makedirs(save_folder)

# %%
def download_images(data):
    for result in data['data']['results']:
        user = result['user']
        name = user['name']
        user_id = user['_id']

        save_dir = f'/Volumes/4TB HD/Tinder_AI Training/Female_Pics/{name}_{user_id}'
        os.makedirs(save_dir, exist_ok=True)

        for i, photo in enumerate(user['photos']):
            photo_url = photo['url']
            save_path = f'{save_dir}/{name}_{user_id}_{i+1}.jpeg'

            response = requests.get(photo_url)
            with open(save_path, "wb") as f:
                f.write(response.content)
            print(f"Downloaded image {i+1} for user {name} ({user_id})")

while True:
    headers = {"X-Auth-Token": auth_key}
    response = requests.get(url, headers=headers)

    data = response.json()
    download_images(data)
    print("Downloaded set 15 second delay has started...")

    time.sleep(15)
# Out:
# Downloaded image 1 for user Gracie (606d61525c895d010068a33c)
# Downloaded image 2 for user Gracie (606d61525c895d010068a33c)
# Downloaded image 3 for user Gracie (606d61525c895d010068a33c)
# Downloaded image 4 for user Gracie (606d61525c895d010068a33c)
# Downloaded image 5 for user Gracie (606d61525c895d010068a33c)
# Downloaded image 6 for user Gracie (606d61525c895d010068a33c)
# Downloaded image 1 for user Madison (62080dfe88a9a7010088e823)
# Downloaded image 2 for user Madison (62080dfe88a9a7010088e823)
# Downloaded image 3 for user Madison (62080dfe88a9a7010088e823)
# Downloaded image 4 for user Madison (62080dfe88a9a7010088e823)
# Downloaded image 5 for user Madison (62080dfe88a9a7010088e823)
# Downloaded image 6 for user Madison (62080dfe88a9a7010088e823)
# Downloaded image 1 for user Koffee (638c2ac0a0be9701007542af)
# Downloaded image 2 for user Koffee (638c2ac0a0be9701007542af)
# Downloaded image 3 for user Koffee (638c2ac0a0be9701007542af)
# ...
